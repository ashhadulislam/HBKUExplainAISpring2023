# %%
from sklearn import datasets
from sklearn.model_selection import train_test_split
import numpy as np
from sklearn.metrics import accuracy_score

from scipy.stats import entropy


import lib as lib

# %% [markdown]
# ### Working on breast cancer data

# %%
# import some data to play with
#load the breast cancer dataset 
bcan = datasets.load_breast_cancer()
X = bcan.data
y = bcan.target

X_train, X_test, y_train, y_test = train_test_split(
     X, y, test_size=0.33, random_state=42)


# normalize the data
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
X_train=scaler.fit_transform(X_train)
X_test=scaler.transform(X_test)

# %%
# initialize params1 and params2

params1=[lib.initialize_weights(X_train.shape[1]) for i in range(100)]# a vector of shape 100,4
# call the initialize_weights function above

params2=[np.random.uniform() for i in range(100)]# a vector of shape 100
# use the np.random.uniform() function

# we have a list of 100 weight vectors (params1) and 100 thresholds (params2)
# convert them to array
params1=np.array(params1)
params2=np.array(params2)


print("Shape of params 1 (weights)",params1.shape)
print("Shape of params 2 (thresholds)",params2.shape)
# Out:
# Shape of params 1 (weights) (100, 30)
# Shape of params 2 (thresholds) (100,)

# %%
z = lib.objective_fn_vector(params1, params2, X_train, y_train)
# Find the global minimum
param1_min = params1[z.argmin()] # use z.argmin()
param2_min = params2[z.argmin()] # use z.argmin()

print("param1_min",param1_min,"param2_min",param2_min)
print(lib.objective_fn(param1_min, param2_min, X_train, y_train))
# Out:
# param1_min [0.49111844 0.35014998 0.11727274 0.68073131 0.59371329 0.56171032
#  0.91435475 0.65313456 0.32065589 0.92833308 0.86465253 0.93920052
#  0.28019744 0.96604908 0.8247242  0.31898057 0.87119707 0.01873225
#  0.05298146 0.71667218 0.02016802 0.52970548 0.90160249 0.15231225
#  0.78460136 0.86846865 0.30577201 0.88191992 0.9022196  0.51128841] param2_min 0.5651867014887214
# 0.6643460978641622

# %%
# Hyper-parameter of the algorithm
c1 = c2 = 0.1
w1 = np.array([np.random.uniform() for i in range(X_train.shape[1])])
w2 = 0.8 
# Create particles
n_particles = 20
np.random.seed(100)
params1=[lib.initialize_weights(X_train.shape[1]) for i in range(n_particles)] # a vector of shape n_particles,4
# call the initialize_weights function above

params2=[np.random.uniform() for i in range(n_particles)]# a vector of shape n_particles
# use the np.random.uniform() function

params1=np.array(params1)
params2=np.array(params2)

print("params1 shape is ",params1.shape,"params2 shape is ",params2.shape)
# Out:
# params1 shape is  (20, 30) params2 shape is  (20,)

# %%
# define velocity of each weight of every particle
V_param1 = [lib.initialize_weights(X_train.shape[1])*0.1 for i in range(n_particles)] # shape is same as params1
# once again can use initialize_weights function

#define velocity of each threshold of every particle
V_param2 = np.array([np.random.uniform()*0.1 for i in range(n_particles)])# shape is same as params2
# once again use np.random.uniform() function

# Initialize objective values
pbest = (params1,params2)
pbest_obj = lib.objective_fn_vector(params1, params2, X_train, y_train)
gbest=(params1[pbest_obj.argmin()],params2[pbest_obj.argmin()])
gbest_obj = pbest_obj.min()

print("pbest obj value for 20 particles are as follows",pbest_obj)
print("gbest obj value among all 20 particles is as follows",gbest_obj)
# note that gbest_obj should be the minimim of all pbest_obj
# Out:
# pbest obj value for 20 particles are as follows [0.6643461 0.6643461 0.6643461 0.6643461 0.6643461 0.6643461 0.6643461
#  0.6643461 0.6643461 0.6643461 0.6643461 0.6643461 0.6643461 0.6643461
#  0.6643461 0.6643461 0.6643461 0.6643461 0.6643461 0.6643461]
# gbest obj value among all 20 particles is as follows 0.6643460978641622

# %%
def update(V_param1,V_param2, params1,params2, pbest, pbest_obj, gbest, gbest_obj):
    "Function to do one iteration of particle swarm optimization"
    # these have been already initialized in the previous cells
    
    # Update params
    r11,r12, r2 = np.random.rand(3)
    V_param1=w1*V_param1+c1*r11*(pbest[0] - params1)+ c2*r2*(gbest[0]-params1)
    V_param2=w2*V_param2+c1*r12*(pbest[1] - params2)+ c2*r2*(gbest[1]-params2)    
#     V = w * V + c1*r11*(pbest - params1) + c2*r2*(gbest.reshape(-1,1)-X)
    params1 = params1 + V_param1
    params2 = params2 + V_param2
    
    obj = lib.objective_fn_vector(params1, params2, X_train, y_train)
    for i in range(pbest[0].shape[0]):
        if pbest_obj[i]>=obj[i]:
            
            pbest[0][i]=params1[i] # update pbest[0][i] with value of params1[i]
            pbest[1][i]=params2[i] # update pbest[1][i] 
            pbest_obj[i]=obj[i]    # also update pbest_obj[i]

            
    gbest=(params1[pbest_obj.argmin()],params2[pbest_obj.argmin()]) # update gbest to contain the best from params1 and params 2
    gbest_obj = pbest_obj.min() # update gbest to get the minimum of pbest_obj

# %%
for i in range(100):
    update(V_param1,V_param2, params1,params2, pbest, pbest_obj, gbest, gbest_obj)
print("PSO found best solution at f({})={}".format(gbest, gbest_obj))
print("Global optimal at f({})={}".format([param1_min,param2_min], lib.objective_fn(param1_min, param2_min, X_train, y_train)))
# Out:
# PSO found best solution at f((array([2.9616904 , 6.46433229, 2.30021511, 5.63653422, 0.12609223,
#        0.36952179, 2.74157393, 1.30673481, 2.67857792, 1.24057144,
#        2.38407915, 0.41198969, 0.23359411, 2.44580337, 4.39544253,
#        8.93547124, 8.62171774, 2.51107622, 3.0258309 , 1.07002231,
#        2.97936566, 1.24684029, 2.38322456, 4.0788889 , 0.72816582,
#        5.59194509, 4.91497731, 1.40804338, 0.83266728, 2.03364854]), 0.4098464718143954))=0.6643460978641622
# Global optimal at f([array([0.49111844, 0.35014998, 0.11727274, 0.68073131, 0.59371329,
#        0.56171032, 0.91435475, 0.65313456, 0.32065589, 0.92833308,
#        0.86465253, 0.93920052, 0.28019744, 0.96604908, 0.8247242 ,
#        0.31898057, 0.87119707, 0.01873225, 0.05298146, 0.71667218,
#        0.02016802, 0.52970548, 0.90160249, 0.15231225, 0.78460136,
#        0.86846865, 0.30577201, 0.88191992, 0.9022196 , 0.51128841]), 0.5651867014887214])=0.6643460978641622

# %%
max_tree_size=128
all_optimized_weights_list=[None for i in range(max_tree_size)]
all_optimized_thresh_list=[None for i in range(max_tree_size)]
all_dataset_sizes_list=[None for i in range(max_tree_size)]
all_IG_list=[None for i in range(max_tree_size)]


def find_best_params(train_x,train_y,test_x,test_y,node_number):
    # Code by bilal
    '''
    recursive function to get the best set of weights
    '''
    print("node_number",node_number,"data shape",train_x.shape)
    # exit condition 1: if the node_number is more than the maximum tree size, return
    if node_number>=max_tree_size:
        return
    # exit condition 2: if the training dataset has one or less rows, return 
    elif train_x.shape[0] <= 1:
      return
      
    
    # exit condition 3: if the train_y has values from only one class (only 0s or only 1s and so on)
    elif len(np.unique(y_train)) == 1:
      return

    # use the initialized lists as global
    global all_optimized_weights_list
    global all_optimized_thresh_list
    global all_dataset_sizes_list
    

    # Hyper-parameter of the algorithm
    c1 = c2 = 0.1
    w1 = np.array([np.random.uniform() for i in range(X_train.shape[1])])
    w2 = 0.8 
    # Create particles
    n_particles = 20
    np.random.seed(100)
    params1=[lib.initialize_weights(X_train.shape[1]) for i in range(n_particles)] # a vector of shape n_particles,n_features
    # call the initialize_weights function above

    params2=[np.random.uniform() for i in range(n_particles)]# a vector of shape n_particles
    # use the np.random.uniform() function

    params1=np.array(params1)
    params2=np.array(params2)

#     print("params1 shape is ",params1.shape,"params2 shape is ",params2.shape)    
    
    # define velocity of each weight of every particle
    V_param1 = [lib.initialize_weights(X_train.shape[1])*0.1 for i in range(n_particles)] # shape is same as params1
    # once again can use initialize_weights function

    #define velocity of each threshold of every particle
    V_param2 = np.array([np.random.uniform()*0.1 for i in range(n_particles)])# shape is same as params2
    # once again use np.random.uniform() function

    # Initialize objective values
    pbest = (params1,params2)
    pbest_obj = lib.objective_fn_vector(params1, params2, X_train, y_train)
    gbest=(params1[pbest_obj.argmin()],params2[pbest_obj.argmin()])
    gbest_obj = pbest_obj.min()

#     print("pbest obj value for 20 particles are as follows",pbest_obj)
#     print("gbest obj value among all 20 particles is as follows",gbest_obj)   
    
    for i in range(100):
        update(V_param1,V_param2, params1,params2, pbest, pbest_obj, gbest, gbest_obj)
#     print("PSO found best solution at f({})={}".format(gbest, gbest_obj))
    
    # add the achieved optimized values to the lists
    all_optimized_weights_list[node_number] = gbest[0]
    all_optimized_thresh_list[node_number] = gbest[1]
    all_dataset_sizes_list[node_number] = train_x.shape[0]
    all_IG_list[node_number] = gbest_obj
    
#     print("threshold is ",gbest[1])
#     print("ys are ",train_y)
    new_ys=np.dot(train_x,gbest[0])
    
    # normalize the new_ys
    new_ys=(new_ys-np.min(new_ys))/(np.max(new_ys) - np.min(new_ys))
#     print("new_ys are",new_ys)
    
    
    # chop the data into two parts: left
    train_x_left=train_x[new_ys>=gbest[1]]
    train_y_left=train_y[new_ys>=gbest[1]]
    left_child_node_num=node_number*2+1

    # chop the data into two parts: right
    train_x_right = train_x[new_ys < gbest[1]]
    train_y_right = train_y[new_ys < gbest[1]]
    right_child_node_num = node_number * 2 + 2
    
    # exit condition 4: return if information gain is 0
    if gbest_obj == 0:
      return
    
    print("Left",train_x_left.shape)
    print("Right",train_x_right.shape)
    # make the recursion call for left
    find_best_params(train_x_left,train_y_left,test_x,test_y,left_child_node_num)
    # make the recursion call for right
    find_best_params(train_x_right,train_y_right,test_x,test_y,right_child_node_num)

# %%
node_number=0
find_best_params(X_train,y_train,X_test,y_test,node_number)
# Out:
# node_number 0 data shape (381, 30)
# Left (99, 30)
# Right (282, 30)
# node_number 1 data shape (99, 30)
# Left (18, 30)
# Right (81, 30)
# node_number 3 data shape (18, 30)
# Left (4, 30)
# Right (14, 30)
# node_number 7 data shape (4, 30)
# Left (2, 30)
# Right (2, 30)
# node_number 15 data shape (2, 30)
# Left (1, 30)
# Right (1, 30)
# node_number 31 data shape (1, 30)
# node_number 32 data shape (1, 30)
# node_number 16 data shape (2, 30)
# Left (1, 30)
# Right (1, 30)
# node_number 33 data shape (1, 30)
# node_number 34 data shape (1, 30)
# node_number 8 data shape (14, 30)
# Left (5, 30)
# Right (9, 30)
# node_number 17 data shape (5, 30)
# Left (4, 30)
# Right (1, 30)
# node_number 35 data shape (4, 30)
# Left (3, 30)
# Right (1, 30)
# node_number 71 data shape (3, 30)
# Left (2, 30)
# Right (1, 30)
# node_number 143 data shape (2, 30)
# node_number 144 data shape (1, 30)
# node_number 72 data shape (1, 30)
# node_number 36 data shape (1, 30)
# node_number 18 data shape (9, 30)
# Left (5, 30)
# Right (4, 30)
# node_number 37 data shape (5, 30)
# Left (3, 30)
# Right (2, 30)
# node_number 75 data shape (3, 30)
# Left (1, 30)
# Right (2, 30)
# node_number 151 data shape (1, 30)
# node_number 152 data shape (2, 30)
# node_number 76 data shape (2, 30)
# Left (1, 30)
# Right (1, 30)
# node_number 153 data shape (1, 30)
# node_number 154 data shape (1, 30)
# node_number 38 data shape (4, 30)
# Left (2, 30)
# Right (2, 30)
# node_number 77 data shape (2, 30)
# Left (1, 30)
# Right (1, 30)
# node_number 155 data shape (1, 30)
# node_number 156 data shape (1, 30)
# node_number 78 data shape (2, 30)
# Left (1, 30)
# Right (1, 30)
# node_number 157 data shape (1, 30)
# node_number 158 data shape (1, 30)
# node_number 4 data shape (81, 30)
# Left (34, 30)
# Right (47, 30)
# node_number 9 data shape (34, 30)
# Left (11, 30)
# Right (23, 30)
# node_number 19 data shape (11, 30)
# Left (8, 30)
# Right (3, 30)
# node_number 39 data shape (8, 30)
# Left (2, 30)
# Right (6, 30)
# node_number 79 data shape (2, 30)
# Left (1, 30)
# Right (1, 30)
# node_number 159 data shape (1, 30)
# node_number 160 data shape (1, 30)
# node_number 80 data shape (6, 30)
# Left (2, 30)
# Right (4, 30)
# node_number 161 data shape (2, 30)
# node_number 162 data shape (4, 30)
# node_number 40 data shape (3, 30)
# Left (2, 30)
# Right (1, 30)
# node_number 81 data shape (2, 30)
# Left (1, 30)
# Right (1, 30)
# node_number 163 data shape (1, 30)
# node_number 164 data shape (1, 30)
# node_number 82 data shape (1, 30)
# node_number 20 data shape (23, 30)
# Left (14, 30)
# Right (9, 30)
# node_number 41 data shape (14, 30)
# Left (8, 30)
# Right (6, 30)
# node_number 83 data shape (8, 30)
# Left (4, 30)
# Right (4, 30)
# node_number 167 data shape (4, 30)
# node_number 168 data shape (4, 30)
# node_number 84 data shape (6, 30)
# Left (4, 30)
# Right (2, 30)
# node_number 169 data shape (4, 30)
# node_number 170 data shape (2, 30)
# node_number 42 data shape (9, 30)
# Left (5, 30)
# Right (4, 30)
# node_number 85 data shape (5, 30)
# Left (2, 30)
# Right (3, 30)
# node_number 171 data shape (2, 30)
# node_number 172 data shape (3, 30)
# node_number 86 data shape (4, 30)
# Left (3, 30)
# Right (1, 30)
# node_number 173 data shape (3, 30)
# node_number 174 data shape (1, 30)
# node_number 10 data shape (47, 30)
# Left (23, 30)
# Right (24, 30)
# node_number 21 data shape (23, 30)
# Left (9, 30)
# Right (14, 30)
# node_number 43 data shape (9, 30)
# Left (4, 30)
# Right (5, 30)
# node_number 87 data shape (4, 30)
# Left (3, 30)
# Right (1, 30)
# node_number 175 data shape (3, 30)
# node_number 176 data shape (1, 30)
# node_number 88 data shape (5, 30)
# Left (3, 30)
# Right (2, 30)
# node_number 177 data shape (3, 30)
# node_number 178 data shape (2, 30)
# node_number 44 data shape (14, 30)
# Left (9, 30)
# Right (5, 30)
# node_number 89 data shape (9, 30)
# Left (4, 30)
# Right (5, 30)
# node_number 179 data shape (4, 30)
# node_number 180 data shape (5, 30)
# node_number 90 data shape (5, 30)
# Left (4, 30)
# Right (1, 30)
# node_number 181 data shape (4, 30)
# node_number 182 data shape (1, 30)
# node_number 22 data shape (24, 30)
# Left (16, 30)
# Right (8, 30)
# node_number 45 data shape (16, 30)
# Left (9, 30)
# Right (7, 30)
# node_number 91 data shape (9, 30)
# Left (5, 30)
# Right (4, 30)
# node_number 183 data shape (5, 30)
# node_number 184 data shape (4, 30)
# node_number 92 data shape (7, 30)
# Left (6, 30)
# Right (1, 30)
# node_number 185 data shape (6, 30)
# node_number 186 data shape (1, 30)
# node_number 46 data shape (8, 30)
# Left (5, 30)
# Right (3, 30)
# node_number 93 data shape (5, 30)
# Left (3, 30)
# Right (2, 30)
# node_number 187 data shape (3, 30)
# node_number 188 data shape (2, 30)
# node_number 94 data shape (3, 30)
# Left (1, 30)
# Right (2, 30)
# node_number 189 data shape (1, 30)
# node_number 190 data shape (2, 30)
# node_number 2 data shape (282, 30)
# Left (149, 30)
# Right (133, 30)
# node_number 5 data shape (149, 30)
# Left (66, 30)
# Right (83, 30)
# node_number 11 data shape (66, 30)
# Left (36, 30)
# Right (30, 30)
# node_number 23 data shape (36, 30)
# Left (22, 30)
# Right (14, 30)
# node_number 47 data shape (22, 30)
# Left (12, 30)
# Right (10, 30)
# node_number 95 data shape (12, 30)
# Left (6, 30)
# Right (6, 30)
# node_number 191 data shape (6, 30)
# node_number 192 data shape (6, 30)
# node_number 96 data shape (10, 30)
# Left (4, 30)
# Right (6, 30)
# node_number 193 data shape (4, 30)
# node_number 194 data shape (6, 30)
# node_number 48 data shape (14, 30)
# Left (10, 30)
# Right (4, 30)
# node_number 97 data shape (10, 30)
# Left (8, 30)
# Right (2, 30)
# node_number 195 data shape (8, 30)
# node_number 196 data shape (2, 30)
# node_number 98 data shape (4, 30)
# Left (2, 30)
# Right (2, 30)
# node_number 197 data shape (2, 30)
# node_number 198 data shape (2, 30)
# node_number 24 data shape (30, 30)
# Left (18, 30)
# Right (12, 30)
# node_number 49 data shape (18, 30)
# Left (14, 30)
# Right (4, 30)
# node_number 99 data shape (14, 30)
# Left (7, 30)
# Right (7, 30)
# node_number 199 data shape (7, 30)
# node_number 200 data shape (7, 30)
# node_number 100 data shape (4, 30)
# Left (3, 30)
# Right (1, 30)
# node_number 201 data shape (3, 30)
# node_number 202 data shape (1, 30)
# node_number 50 data shape (12, 30)
# Left (8, 30)
# Right (4, 30)
# node_number 101 data shape (8, 30)
# Left (4, 30)
# Right (4, 30)
# node_number 203 data shape (4, 30)
# node_number 204 data shape (4, 30)
# node_number 102 data shape (4, 30)
# Left (3, 30)
# Right (1, 30)
# node_number 205 data shape (3, 30)
# node_number 206 data shape (1, 30)
# node_number 12 data shape (83, 30)
# Left (34, 30)
# Right (49, 30)
# node_number 25 data shape (34, 30)
# Left (21, 30)
# Right (13, 30)
# node_number 51 data shape (21, 30)
# Left (15, 30)
# Right (6, 30)
# node_number 103 data shape (15, 30)
# Left (9, 30)
# Right (6, 30)
# node_number 207 data shape (9, 30)
# node_number 208 data shape (6, 30)
# node_number 104 data shape (6, 30)
# Left (3, 30)
# Right (3, 30)
# node_number 209 data shape (3, 30)
# node_number 210 data shape (3, 30)
# node_number 52 data shape (13, 30)
# Left (7, 30)
# Right (6, 30)
# node_number 105 data shape (7, 30)
# Left (5, 30)
# Right (2, 30)
# node_number 211 data shape (5, 30)
# node_number 212 data shape (2, 30)
# node_number 106 data shape (6, 30)
# Left (4, 30)
# Right (2, 30)
# node_number 213 data shape (4, 30)
# node_number 214 data shape (2, 30)
# node_number 26 data shape (49, 30)
# Left (31, 30)
# Right (18, 30)
# node_number 53 data shape (31, 30)
# Left (17, 30)
# Right (14, 30)
# node_number 107 data shape (17, 30)
# Left (9, 30)
# Right (8, 30)
# node_number 215 data shape (9, 30)
# node_number 216 data shape (8, 30)
# node_number 108 data shape (14, 30)
# Left (10, 30)
# Right (4, 30)
# node_number 217 data shape (10, 30)
# node_number 218 data shape (4, 30)
# node_number 54 data shape (18, 30)
# Left (10, 30)
# Right (8, 30)
# node_number 109 data shape (10, 30)
# Left (5, 30)
# Right (5, 30)
# node_number 219 data shape (5, 30)
# node_number 220 data shape (5, 30)
# node_number 110 data shape (8, 30)
# Left (6, 30)
# Right (2, 30)
# node_number 221 data shape (6, 30)
# node_number 222 data shape (2, 30)
# node_number 6 data shape (133, 30)
# Left (108, 30)
# Right (25, 30)
# node_number 13 data shape (108, 30)
# Left (62, 30)
# Right (46, 30)
# node_number 27 data shape (62, 30)
# Left (41, 30)
# Right (21, 30)
# node_number 55 data shape (41, 30)
# Left (23, 30)
# Right (18, 30)
# node_number 111 data shape (23, 30)
# Left (14, 30)
# Right (9, 30)
# node_number 223 data shape (14, 30)
# node_number 224 data shape (9, 30)
# node_number 112 data shape (18, 30)
# Left (8, 30)
# Right (10, 30)
# node_number 225 data shape (8, 30)
# node_number 226 data shape (10, 30)
# node_number 56 data shape (21, 30)
# Left (10, 30)
# Right (11, 30)
# node_number 113 data shape (10, 30)
# Left (7, 30)
# Right (3, 30)
# node_number 227 data shape (7, 30)
# node_number 228 data shape (3, 30)
# node_number 114 data shape (11, 30)
# Left (4, 30)
# Right (7, 30)
# node_number 229 data shape (4, 30)
# node_number 230 data shape (7, 30)
# node_number 28 data shape (46, 30)
# Left (31, 30)
# Right (15, 30)
# node_number 57 data shape (31, 30)
# Left (19, 30)
# Right (12, 30)
# node_number 115 data shape (19, 30)
# Left (12, 30)
# Right (7, 30)
# node_number 231 data shape (12, 30)
# node_number 232 data shape (7, 30)
# node_number 116 data shape (12, 30)
# Left (3, 30)
# Right (9, 30)
# node_number 233 data shape (3, 30)
# node_number 234 data shape (9, 30)
# node_number 58 data shape (15, 30)
# Left (7, 30)
# Right (8, 30)
# node_number 117 data shape (7, 30)
# Left (4, 30)
# Right (3, 30)
# node_number 235 data shape (4, 30)
# node_number 236 data shape (3, 30)
# node_number 118 data shape (8, 30)
# Left (3, 30)
# Right (5, 30)
# node_number 237 data shape (3, 30)
# node_number 238 data shape (5, 30)
# node_number 14 data shape (25, 30)
# Left (16, 30)
# Right (9, 30)
# node_number 29 data shape (16, 30)
# Left (7, 30)
# Right (9, 30)
# node_number 59 data shape (7, 30)
# Left (3, 30)
# Right (4, 30)
# node_number 119 data shape (3, 30)
# Left (1, 30)
# Right (2, 30)
# node_number 239 data shape (1, 30)
# node_number 240 data shape (2, 30)
# node_number 120 data shape (4, 30)
# Left (1, 30)
# Right (3, 30)
# node_number 241 data shape (1, 30)
# node_number 242 data shape (3, 30)
# node_number 60 data shape (9, 30)
# Left (7, 30)
# Right (2, 30)
# node_number 121 data shape (7, 30)
# Left (4, 30)
# Right (3, 30)
# node_number 243 data shape (4, 30)
# node_number 244 data shape (3, 30)
# node_number 122 data shape (2, 30)
# Left (1, 30)
# Right (1, 30)
# node_number 245 data shape (1, 30)
# node_number 246 data shape (1, 30)
# node_number 30 data shape (9, 30)
# Left (4, 30)
# Right (5, 30)
# node_number 61 data shape (4, 30)
# Left (2, 30)
# Right (2, 30)
# node_number 123 data shape (2, 30)
# Left (1, 30)
# Right (1, 30)
# node_number 247 data shape (1, 30)
# node_number 248 data shape (1, 30)
# node_number 124 data shape (2, 30)
# Left (1, 30)
# Right (1, 30)
# node_number 249 data shape (1, 30)
# node_number 250 data shape (1, 30)
# node_number 62 data shape (5, 30)
# Left (4, 30)
# Right (1, 30)
# node_number 125 data shape (4, 30)
# Left (1, 30)
# Right (3, 30)
# node_number 251 data shape (1, 30)
# node_number 252 data shape (3, 30)
# node_number 126 data shape (1, 30)

# %%
X_train.shape
# Out:
# (381, 30)

# %%
all_optimized_thresh_list
# Out:
# [0.4098464718143954,
#  0.4098464718143954,
#  0.4098464718143954,
#  0.4098464718143954,
#  0.4098464718143954,
#  0.4098464718143954,
#  0.4098464718143954,
#  0.4098464718143954,
#  0.4098464718143954,
#  0.4098464718143954,
#  0.4098464718143954,
#  0.4098464718143954,
#  0.4098464718143954,
#  0.4098464718143954,
#  0.4098464718143954,
#  0.4098464718143954,
#  0.4098464718143954,
#  0.4098464718143954,
#  0.4098464718143954,
#  0.4098464718143954,
#  0.4098464718143954,
#  0.4098464718143954,
#  0.4098464718143954,
#  0.4098464718143954,
#  0.4098464718143954,
#  0.4098464718143954,
#  0.4098464718143954,
#  0.4098464718143954,
#  0.4098464718143954,
#  0.4098464718143954,
#  0.4098464718143954,
#  None,
#  None,
#  None,
#  None,
#  0.4098464718143954,
#  None,
#  0.4098464718143954,
#  0.4098464718143954,
#  0.4098464718143954,
#  0.4098464718143954,
#  0.4098464718143954,
#  0.4098464718143954,
#  0.4098464718143954,
#  0.4098464718143954,
#  0.4098464718143954,
#  0.4098464718143954,
#  0.4098464718143954,
#  0.4098464718143954,
#  0.4098464718143954,
#  0.4098464718143954,
#  0.4098464718143954,
#  0.4098464718143954,
#  0.4098464718143954,
#  0.4098464718143954,
#  0.4098464718143954,
#  0.4098464718143954,
#  0.4098464718143954,
#  0.4098464718143954,
#  0.4098464718143954,
#  0.4098464718143954,
#  0.4098464718143954,
#  0.4098464718143954,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  0.4098464718143954,
#  None,
#  None,
#  None,
#  0.4098464718143954,
#  0.4098464718143954,
#  0.4098464718143954,
#  0.4098464718143954,
#  0.4098464718143954,
#  0.4098464718143954,
#  0.4098464718143954,
#  None,
#  0.4098464718143954,
#  0.4098464718143954,
#  0.4098464718143954,
#  0.4098464718143954,
#  0.4098464718143954,
#  0.4098464718143954,
#  0.4098464718143954,
#  0.4098464718143954,
#  0.4098464718143954,
#  0.4098464718143954,
#  0.4098464718143954,
#  0.4098464718143954,
#  0.4098464718143954,
#  0.4098464718143954,
#  0.4098464718143954,
#  0.4098464718143954,
#  0.4098464718143954,
#  0.4098464718143954,
#  0.4098464718143954,
#  0.4098464718143954,
#  0.4098464718143954,
#  0.4098464718143954,
#  0.4098464718143954,
#  0.4098464718143954,
#  0.4098464718143954,
#  0.4098464718143954,
#  0.4098464718143954,
#  0.4098464718143954,
#  0.4098464718143954,
#  0.4098464718143954,
#  0.4098464718143954,
#  0.4098464718143954,
#  0.4098464718143954,
#  0.4098464718143954,
#  0.4098464718143954,
#  0.4098464718143954,
#  0.4098464718143954,
#  0.4098464718143954,
#  0.4098464718143954,
#  0.4098464718143954,
#  0.4098464718143954,
#  0.4098464718143954,
#  0.4098464718143954,
#  None,
#  None]

# %%
thresh=all_optimized_thresh_list[0]
