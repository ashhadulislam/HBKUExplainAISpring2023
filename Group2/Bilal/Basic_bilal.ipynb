# %%
from sklearn import datasets
from sklearn.model_selection import train_test_split
import numpy as np
from sklearn.metrics import accuracy_score

from scipy.stats import entropy


# import some data to play with
iris = datasets.load_iris()
X = iris.data
y = iris.target

X_train, X_test, y_train, y_test = train_test_split(
     X, y, test_size=0.33, random_state=42)

# def change_weights(X_train,y_train,X_test,y_test,weights):

# %%
# Check if the entropy functions work

# %%
pk = np.array([1/5, 2/5, 2/5])  # fair coin
H = entropy(pk)
print(H)
# Out:
# 1.0549201679861442

# %%
H=-0.2*(np.log(0.2))-0.4*(np.log(0.4))-0.4*(np.log(0.4))
print(H)
# Out:
# 1.0549201679861442

# %%
def calculate_probabilities(list_labels,uniq_labels):
    '''
    this function calculates the probabilities of each label in the list of labels
    it is calculated by number of labels in class A/all labels
    number of labels in class B/all labels
    and so on
    '''

    # Code by bilal
    probabilities = []
    total_labels = len(list_labels)

    for element in uniq_labels:
      element_count = list_labels.count(element)
      proba = (element_count/total_labels)
      probabilities.append(proba)
    
    #print("probabilities = ", probabilities)


    
    # put your code here
    return probabilities
    
    
    
# test your function
list_labels=[1,2,0,1,2,0]
uniq_labels=[0,1,2]
print(calculate_probabilities(list_labels,uniq_labels))
# this should print somehting like 0.33,0.33,0.33
# Out:
# [0.3333333333333333, 0.3333333333333333, 0.3333333333333333]

# %%
def calc_entropy_from_probabilities(list_probas):
    '''
    list_probas is the list of probabiities
    the formula for entropy is
    sum(-proba*log(proba))
    
    '''
    # Code by bilal

    entropy = 0

    for element in list_probas:
      entropy = entropy - (element*(np.log(element)))
    
    

    # for now returning the same list
    # put your code to calculate entropy
    return entropy

# test your function
list_probas=[1/5, 2/5, 2/5]
print(calc_entropy_from_probabilities(list_probas))
# above should print 1.054...
# Out:
# 1.0549201679861442

# %%
def information_gain(old_entropy,new_entropies,count_items):
    '''
    from the list of new entropies, calculate the overall new entropy
    
    formula is something like:
    overall_new_entropy = entropy1*proportion1 + entropy2*proportion2+ entropy3*proportion3 ...
    
    igain=old_entropy-overall_new_entropy
    '''
    # Code by bilal
    
    overall_new_entropy = 0

    for index , new_entropy in enumerate(new_entropies):
      overall_new_entropy += new_entropy * (count_items[index]/(sum(count_items)))

    igain = old_entropy - overall_new_entropy 
    
    return igain


#test your function
old_entropy=1
new_entropies=[0,0.65]
count_items=[4,6]
print(information_gain(old_entropy,new_entropies,count_items))
# above should print 0.61
# Out:
# 0.61

# %%
# X

# %%
# iris

# %%
num_feats=X_train.shape[1]
def initialize_weights(number_features):
    '''
    the first set of weights corresponding to the features
    defaults to 1
    '''
    
    weights=np.array([2 for i in range(number_features)])
    return weights

# %%
print(initialize_weights(num_feats))
# Out:
# [2 2 2 2]

# %%
y_test
# Out:
# array([1, 0, 2, 1, 1, 0, 1, 2, 1, 1, 2, 0, 0, 0, 0, 1, 2, 1, 1, 2, 0, 2,
#        0, 2, 2, 2, 2, 2, 0, 0, 0, 0, 1, 0, 0, 2, 1, 0, 0, 0, 2, 1, 1, 0,
#        0, 1, 2, 2, 1, 2])

# %%
def change_weights(weights):
    new_weights=[]
    for i in range(weights[-1].shape[0]):
        new_weights.append(np.random.uniform(0,1))
    return np.array(new_weights)

# %%
def apply_and_measure_accuracy(X,y,weights):    
    res=np.sum(X*weights[-1],axis=1)
    res = np.tanh(res)
    res[res>0.5]=1
    res[res<=0.5]=0
    acc=accuracy_score(y, res)
    return acc
    
def get_train_test_accuracy(X_train,y_train,X_test,y_test,weights):
    train_acc=apply_and_measure_accuracy(X_train,y_train,weights)
    test_acc=apply_and_measure_accuracy(X_test,y_test,weights)
    return train_acc,test_acc

# %%
wt_init=[initialize_weights(num_feats)]
res=np.sum(X_test*wt_init[-1],axis=1)
res = np.tanh(res)
res[res>0.5]=1
res[res<=0.5]=0
print(res.shape)
acc=accuracy_score(y_test, res)
test_accuracies=[acc]

res=np.sum(X_train*wt_init[-1],axis=1)
res = np.tanh(res)
res[res>0.5]=1
res[res<=0.5]=0
print(res.shape)
acc=accuracy_score(y_train, res)

train_accuracies=[acc]
print("Initial test acc",test_accuracies)




def train_weights(X_train,y_train,X_test,y_test,weights,train_accuracies,test_accuracies):
    print("Trial number ",len(weights))
    
    train_acc,test_acc=get_train_test_accuracy(X_train,y_train,X_test,y_test,weights)
    
    
    
    # store the accuracy in this list of accuracies
    train_accuracies.append(train_acc)
    test_accuracies.append(test_acc)
    print("train",train_acc,"test",test_acc)
    print(test_accuracies[-1],test_accuracies[-2])
    
    # exit condition
    if test_accuracies[-1]<test_accuracies[-2]:
        print("returning")
        return weights,train_accuracies,test_accuracies
    
    # change the weights according to the accuracy
    new_weights=change_weights(weights)
    weights.append(new_weights)
    return train_weights(X_train,y_train,X_test,y_test,weights,train_accuracies,test_accuracies)
# Out:
# (50,)
# (100,)
# Initial test acc [0.3]

# %%
weights,train_accuracies,test_accuracies=train_weights(X_train,y_train,X_test,y_test,wt_init,train_accuracies,test_accuracies)
# Out:
# Trial number  1
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  2
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  3
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  4
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  5
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  6
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  7
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  8
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  9
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  10
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  11
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  12
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  13
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  14
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  15
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  16
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  17
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  18
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  19
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  20
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  21
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  22
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  23
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  24
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  25
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  26
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  27
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  28
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  29
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  30
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  31
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  32
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  33
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  34
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  35
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  36
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  37
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  38
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  39
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  40
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  41
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  42
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  43
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  44
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  45
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  46
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  47
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  48
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  49
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  50
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  51
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  52
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  53
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  54
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  55
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  56
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  57
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  58
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  59
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  60
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  61
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  62
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  63
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  64
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  65
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  66
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  67
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  68
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  69
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  70
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  71
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  72
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  73
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  74
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  75
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  76
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  77
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  78
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  79
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  80
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  81
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  82
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  83
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  84
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  85
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  86
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  87
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  88
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  89
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  90
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  91
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  92
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  93
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  94
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  95
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  96
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  97
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  98
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  99
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  100
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  101
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  102
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  103
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  104
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  105
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  106
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  107
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  108
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  109
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  110
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  111
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  112
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  113
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  114
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  115
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  116
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  117
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  118
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  119
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  120
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  121
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  122
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  123
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  124
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  125
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  126
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  127
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  128
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  129
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  130
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  131
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  132
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  133
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  134
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  135
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  136
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  137
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  138
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  139
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  140
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  141
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  142
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  143
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  144
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  145
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  146
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  147
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  148
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  149
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  150
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  151
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  152
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  153
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  154
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  155
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  156
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  157
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  158
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  159
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  160
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  161
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  162
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  163
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  164
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  165
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  166
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  167
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  168
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  169
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  170
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  171
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  172
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  173
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  174
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  175
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  176
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  177
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  178
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  179
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  180
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  181
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  182
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  183
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  184
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  185
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  186
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  187
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  188
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  189
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  190
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  191
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  192
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  193
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  194
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  195
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  196
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  197
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  198
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  199
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  200
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  201
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  202
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  203
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  204
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  205
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  206
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  207
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  208
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  209
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  210
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  211
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  212
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  213
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  214
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  215
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  216
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  217
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  218
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  219
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  220
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  221
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  222
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  223
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  224
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  225
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  226
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  227
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  228
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  229
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  230
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  231
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  232
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  233
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  234
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  235
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  236
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  237
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  238
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  239
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  240
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  241
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  242
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  243
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  244
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  245
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  246
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  247
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  248
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  249
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  250
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  251
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  252
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  253
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  254
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  255
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  256
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  257
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  258
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  259
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  260
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  261
# train 0.35 test 0.3
# 0.3 0.3
# Trial number
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  668
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  669
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  670
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  671
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  672
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  673
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  674
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  675
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  676
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  677
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  678
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  679
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  680
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  681
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  682
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  683
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  684
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  685
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  686
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  687
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  688
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  689
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  690
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  691
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  692
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  693
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  694
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  695
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  696
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  697
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  698
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  699
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  700
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  701
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  702
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  703
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  704
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  705
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  706
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  707
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  708
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  709
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  710
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  711
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  712
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  713
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  714
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  715
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  716
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  717
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  718
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  719
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  720
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  721
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  722
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  723
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  724
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  725
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  726
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  727
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  728
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  729
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  730
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  731
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  732
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  733
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  734
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  735
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  736
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  737
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  738
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  739
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  740
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  741
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  742
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  743
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  744
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  745
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  746
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  747
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  748
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  749
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  750
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  751
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  752
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  753
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  754
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  755
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  756
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  757
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  758
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  759
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  760
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  761
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  762
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  763
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  764
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  765
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  766
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  767
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  768
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  769
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  770
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  771
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  772
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  773
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  774
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  775
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  776
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  777
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  778
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  779
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  780
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  781
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  782
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  783
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  784
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  785
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  786
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  787
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  788
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  789
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  790
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  791
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  792
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  793
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  794
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  795
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  796
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  797
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  798
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  799
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  800
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  801
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  802
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  803
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  804
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  805
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  806
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  807
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  808
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  809
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  810
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  811
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  812
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  813
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  814
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  815
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  816
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  817
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  818
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  819
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  820
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  821
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  822
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  823
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  824
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  825
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  826
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  827
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  828
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  829
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  830
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  831
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  832
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  833
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  834
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  835
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  836
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  837
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  838
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  839
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  840
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  841
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  842
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  843
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  844
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  845
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  846
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  847
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  848
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  849
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  850
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  851
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  852
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  853
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  854
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  855
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  856
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  857
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  858
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  859
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  860
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  861
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  862
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  863
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  864
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  865
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  866
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  867
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  868
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  869
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  870
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  871
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  872
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  873
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  874
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  875
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  876
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  877
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  878
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  879
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  880
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  881
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  882
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  883
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  884
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  885
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  886
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  887
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  888
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  889
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  890
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  891
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  892
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  893
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  894
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  895
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  896
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  897
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  898
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  899
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  900
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  901
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  902
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  903
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  904
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  905
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  906
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  907
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  908
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  909
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  910
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  911
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  912
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  913
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  914
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  915
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  916
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  917
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  918
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  919
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  920
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  921
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  922
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  923
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  924
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  925
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  926
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  927
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  928
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  929
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  930
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  931
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  932
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  933
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  934
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  935
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  936
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  937
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  938
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  939
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  940
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  941
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  942
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  943
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  944
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  945
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  946
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  947
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  948
# train 0.35 test 0.3
# 0.3 0.3
# Trial number  949
# ---------------------------------------------------------------------------
# RecursionError                            Traceback (most recent call last)
# <ipython-input-27-a9410fbce87c> in <module>
# ----> 1 weights,train_accuracies,test_accuracies=train_weights(X_train,y_train,X_test,y_test,wt_init,train_accuracies,test_accuracies)
#
# <ipython-input-26-2caebf019c4e> in train_weights(X_train, y_train, X_test, y_test, weights, train_accuracies, test_accuracies)
#      42     new_weights=change_weights(weights)
#      43     weights.append(new_weights)
# ---> 44     return train_weights(X_train,y_train,X_test,y_test,weights,train_accuracies,test_accuracies)
#      45
#
# ... last 1 frames repeated, from the frame below ...
#
# <ipython-input-26-2caebf019c4e> in train_weights(X_train, y_train, X_test, y_test, weights, train_accuracies, test_accuracies)
#      42     new_weights=change_weights(weights)
#      43     weights.append(new_weights)
# ---> 44     return train_weights(X_train,y_train,X_test,y_test,weights,train_accuracies,test_accuracies)
#      45
#
# RecursionError: maximum recursion depth exceeded while calling a Python object

# %%
### Test the weights in the pre-final iteration
res=np.sum(X_test*weights[-2],axis=1)
res = np.tanh(res)
res[res>0.5]=1
res[res<=0.5]=0
acc=accuracy_score(y_test, res)
print(acc)
print(res)
